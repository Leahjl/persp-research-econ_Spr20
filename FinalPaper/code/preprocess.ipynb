# %%
import numpy
import pandas
import re
import nltk
import wordcloud

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('tagsets') 
nltk.download('stopwords')
nltk.download('wordnet')

from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem.wordnet import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from gensim import corpora, models
from langdetect import detect
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from datetime import datetime as dt
import seaborn as sb
from os import path
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# [nltk_data] Downloading package punkt to /Users/hejielu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/hejielu/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package tagsets to /Users/hejielu/nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/hejielu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/hejielu/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df1 = pandas.read_csv('/Users/hejielu/Desktop/final/cleandata.csv')
df1.head()
# Out:
#   dateoftweet                                               text
# 0  03/05/2020  suck everyday don t security people infiltrate...
# 1  03/05/2020  s democrat front runner tonight metoo activist...
# 2  03/05/2020  housing training pay aggrieved female resident...
# 3  03/05/2020  gaining traction metoo movement victim patel s...
# 4  03/05/2020       onair chill take midol democrat pollster kil

# %%
df2 = pandas.read_csv('/Users/hejielu/Desktop/metoo.csv')
df2.head()
# Out:
#   dateoftweet                                               text
# 0  06/03/2020  israeli priviledge matt lauer somehow jail bac...
# 1  06/03/2020  normal viewing documentary netflix essential s...
# 2  06/03/2020              wish say story need voice suppo metoo
# 3  06/03/2020  psst saw bit blackout tuesday point previous t...
# 4  06/03/2020  rivera hus hea see many former female student ...

# %%
def merge(df1,df2):
    '''
    Merge two dataframe
    
    Inputs:
      df1: dataframe consists of existed data
      df2: dataframe consists of data crawled from twitter api

    Outputs:
      a cleaned dataframe
    '''
    df1_cleaned = preprocess(df1)
    df2_cleaned = preprocess(df2)
    df_total = pandas.concat([df2_cleaned, df1_cleaned],axis=0,ignore_index=True)
    df_total.replace('', np.nan, inplace=True)
    for row in df_total.itertuples(index=False):
        if detect(str(row[1])) != 'en':
            df_total['text'].replace(row[1], np.nan, inplace=True)
    df_total.drop_duplicates(subset='text', keep="first")
    df_total.dropna(how='all', subset=['text'], inplace=True)
    return df_total

# %%
df_

# %%
df_t.to_csv('/Users/hejielu/Desktop/data.csv', index=False, encoding='utf-8')

# %%
df_total = pandas.read_csv('/Users/hejielu/Desktop/final/data.csv')

# %%
df_total.replace('', np.nan, inplace=True)

df_total.dropna(how='all', subset=['text'], inplace=True)

# %%
df_total.drop_duplicates(subset='text', keep="first")
# Out:
#        dateoftweet                                               text
# 0       03/05/2020  suck everyday don t security people infiltrate...
# 1       03/05/2020  heavy way desi understand merajismmerimarzi me...
# 2       03/05/2020  s democrat front runner tonight metoo activist...
# 3       03/05/2020  housing training pay aggrieved female resident...
# 4       03/05/2020  gaining traction metoo movement victim patel s...
# 5       03/05/2020  priti patel allegation turning metoo moment ci...
# 6       03/05/2020       onair chill take midol democrat pollster kil
# 7       03/05/2020  left drastically misfired bernie running caign...
# 8       03/05/2020  womenshistorymonth re remembering survivor rec...
# 9       03/05/2020  truly candidate generational change occupy met...
# 10      03/05/2020  f ing useless civil servant patel refers unenv...
# 11      03/05/2020     different time let s thankful metoo movement w
# ...

# %%
df_total.to_csv('/Users/hejielu/Desktop/cleandata.csv', index=False, encoding='utf-8')

# %%
df_test = pandas.read_csv('/Users/hejielu/Desktop/cleandata.csv')

# %%
df_test.to_csv('/Users/hejielu/Desktop/finaldata.csv', index=False, encoding='utf-8')

# %%
df = pandas.read_csv('/Users/hejielu/Desktop/finaldata.csv')

# %%
df.replace('', np.nan, inplace=True)

df.dropna(how='all', subset=['text'], inplace=True)

# %%
df.drop_duplicates(subset='text', keep="first", inplace=True)

# %%
df.to_csv('/Users/hejielu/Desktop/cdata.csv', index=False, encoding='utf-8')
